# %% [markdown]
# Digital Signal Processing Lab,Week-1,Experiment-1

# %% [markdown]
# Sujan S Ramesh
# 191EE251

# %%
import numpy as np
import scipy as sp
import math as m
import IPython

from scipy import signal as sp
from scipy.io import wavfile
from scipy.io.wavfile import write
from scipy.fft import fft, ifft

from matplotlib import pyplot as plt
from matplotlib import style
from matplotlib import rcParams

# %matplotlib inline

plt.style.use(['seaborn-deep'])
plt.rcParams.update({
    "font.serif": ["cm"],
    "mathtext.fontset": "cm",
    "figure.figsize": (12,6),
    "font.size": 8})

# %% [markdown]
# Problem -1

# %%
alpha = 1 + 251%3
alpha
# Out:
# 3

# %%
t=np.linspace(0,10,1000)
x1 = np.exp(-alpha*t)
x2 = np.exp(-alpha*(t-1.5*alpha))
x3 = np.exp(2*alpha*t)

# plt.plot(t,x1)

# plt.plot(t,x2)

plt.plot(t,x3)

plt.ylabel("x(2*t)")
plt.xlabel("t")
# Out:
# Text(0.5, 0, 't')

# %%
w=np.linspace(-m.pi,m.pi,1000)
Xw_mag = [1/m.sqrt(9+w*w) for w in w]
Xw_phase = [np.arctan(w/3) for w in w]
# plt.plot(w, Xw_mag)
# plt.xlabel("w")
# plt.ylabel("|x(w)|")
plt.plot(w, Xw_phase)
plt.xlabel("w")
plt.ylabel("<x(w)")
# Out:
# Text(0, 0.5, '<x(w)')

# %% [markdown]
# Problem - 2

# %%
f1=200*alpha
f2=220*alpha
time = np.linspace(0,5000*0.001,5000)
s1 = [m.sin(2*m.pi*f1*t) for t in time]
s2 = [m.sin(2*m.pi*f2*t) for t in time]
s_append = s1 + s1
s_append = np.array(s_append)
write('p2.wav', 1000, s_append.astype(np.float32))
plt.subplot(2,1,1)
plt.plot(t[0:100],s_append[0:100])
plt.subplot(2,1,2)
plt.stem(s_append[0:100])
# Out:
# C:\Users\sujan\anaconda3\lib\site-packages\ipykernel_launcher.py:12: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   if sys.path[0] == '':
# <StemContainer object of 3 artists>

# %% [markdown]
# Problem - 3

# %%
h=np.loadtxt('ConvFile3.txt',dtype = float)
F,x = wavfile.read('Track003.wav')
x=x[:,0]
conv=sp.convolve(x,h)
write('p3.wav', F, (conv).astype("float32"))
X=fft(np.array(x))
Y=fft(np.array(conv))
plt.subplot(511)
plt.plot(x)
plt.subplot(512)
plt.plot(h)
plt.subplot(513)
plt.plot(conv)
plt.subplot(514)
plt.plot(np.abs(X))
plt.subplot(515)
plt.plot(np.abs(Y))

# %% [markdown]
# Problem -4

# %%
F1,x1 = wavfile.read('speech.wav')
y1 = [x1*m.cos(2*m.pi*(500/F1)*n) for n in range(F1)]
plt.magnitude_spectrum(y1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-826d7b5312f7> in <module>
#       1 F1,x1 = wavfile.read('speech.wav')
#       2 y1 = [x1*m.cos(2*m.pi*(500/F1)*n) for n in range(F1)]
# ----> 3 plt.magnitude_spectrum(y1)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in magnitude_spectrum(x, Fs, Fc, window, pad_to, sides, scale, data, **kwargs)
#    2713         x, Fs=Fs, Fc=Fc, window=window, pad_to=pad_to, sides=sides,
#    2714         scale=scale, **({"data": data} if data is not None else {}),
# -> 2715         **kwargs)
#    2716
#    2717
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
# ...
