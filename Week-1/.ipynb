# %% [markdown]
# Digital Signal Processing Lab,Week-1,Experiment-1

# %% [markdown]
# Sujan S Ramesh
# 191EE251

# %%
import numpy as np
import scipy as sp
import math as m
import IPython

from scipy import signal as sp
from scipy.io import wavfile

from matplotlib import pyplot as plt
from matplotlib import style
from matplotlib import rcParams

# %matplotlib inline

plt.style.use(['seaborn-deep'])
plt.rcParams.update({
    "font.serif": ["cm"],
    "mathtext.fontset": "cm",
    "figure.figsize": (12,6),
    "font.size": 24})

# %% [markdown]
# Problem -1

# %%
alpha = 1 + 251%3
alpha
# Out:
# 3

# %%
t=np.linspace(0,10,1000)
x1 = np.exp(-alpha*t)
x2 = np.exp(-alpha*(t-1.5*alpha))
x3 = np.exp(2*alpha*t)

# plt.plot(t,x1)

# plt.plot(t,x2)

plt.plot(t,x3)

plt.ylabel("x(2*t)")
plt.xlabel("t")
# Out:
# Text(0.5, 0, 't')

# %%
w=np.linspace(-m.pi,m.pi,1000)
Xw_mag = [1/m.sqrt(9+w*w) for w in w]
Xw_phase = [np.arctan(w/3) for w in w]
# plt.plot(w, Xw_mag)
# plt.xlabel("w")
# plt.ylabel("|x(w)|")
plt.plot(w, Xw_phase)
plt.xlabel("w")
plt.ylabel("<x(w)")
# Out:
# Text(0, 0.5, '<x(w)')

# %% [markdown]
# Problem - 2

# %%
f1=200*alpha
f2=220*alpha
t = np.linspace(0,5000*0.001,5000)
s1 = [m.sin(2*m.pi*f1*t) for t in t]
s2 = [m.sin(2*m.pi*f2*t) for t in t]
s_append = s1
for i in s1 :
    s_append.append(i)
